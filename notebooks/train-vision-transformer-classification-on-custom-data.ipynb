# %% [markdown]
# ## Training the Vision Transformer on a Custom Dataset
#
# In this notebook, we are going to fine-tune a pre-trained Vision Transformer (which can be found from [Huggingface](https://github.com/huggingface/transformers)) on a Custom Dataset. For this notebook we will be using the Rock, Paper, Scissors dataset which can be found [here](https://public.roboflow.com/classification/rock-paper-scissors/1). This dataset is a collection of 2925 images images in 3 different classes. This tutorial is based on Huggingface's [Fine tuning the Vision Transformer on CIFAR 10 notebook](https://colab.research.google.com/github/NielsRogge/Transformers-Tutorials/blob/master/VisionTransformer/Fine_tuning_the_Vision_Transformer_on_CIFAR_10_with_the_%F0%9F%A4%97_Trainer.ipynb).
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [How to Train the HuggingFace Vision Transformer On a Custom Dataset](blog.roboflow.com/how-to-train-the-huggingface-vision-transformer-on-a-custom-dataset/) concurrently.
#
#
# We will prepare the data using [Roboflow's Preprocessing Tools](https://docs.roboflow.com/image-transformations/image-preprocessing), and train the model using this notebook.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train a Vision Transformer on your custom classification data.
#
# To train our image classifier we take the following steps:
#
# * Install Vision Transformer dependencies
# * Download custom Image Classification data using Roboflow
# * Use the Vision Transformer Feature Extractor
# * Run the Vision Transformer training procedure
# * Evaluate the Vision Transformer on a test image
# * Export the Vision Transformer model for future inference
#
#
# ### **About**
#
# [Roboflow](https://roboflow.com) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# **Looking for a vision model available via API without hassle? Try Roboflow Train.**
#
# ![Roboflow Wordmark](https://i.imgur.com/dcLNMhV.png)

# %% [markdown]
# Let's start by installing the relevant libraries.

# %%
# !pip install -q git+https://github.com/huggingface/transformers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done

# %% [markdown]
# # Download the Data
#
# We'll preprocess and download our dataset from Roboflow. To preprocess the images, change the size of the image to 224x224. To download the dataset, use the "**Folder Structure**" export format.
#
# To get your data into Roboflow, follow the [Getting Started Guide](https://blog.roboflow.ai/getting-started-with-roboflow/).
#
# Note: This data has already been preprocessed through Roboflow; we HIGHLY reccommend you follow the [accompanying blog](blog.roboflow.com/how-to-train-the-huggingface-vision-transformer-on-a-custom-dataset/) as you go through this notebook.
#
# ![folder.PNG](data:image/png;base64,...)

# %%
# !curl -L "https://universe.roboflow.com/ds/QDMCm8ce12?key=3eQaf732dP" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: valid/Negative/13987_jpg.rf.7fef6a522a3b7cb3b017d766371e8940.jpg
#  extracting: valid/Negative/13988_jpg.rf.c144ff22282be908aba402b3d0be5083.jpg
#  extracting: valid/Negative/13997_jpg.rf.8fe4a0b9979fe7d5c1fd4ff68fb4b32a.jpg
#  extracting: valid/Negative/13999_jpg.rf.829ba3688bd89dd2ecbe4d3249d1a0a1.jpg
#  extracting: valid/Negative/14005_jpg.rf.b8ab06f31258f3bf2a46fe9fb710e6d6.jpg
#  extracting: valid/Negative/14012_jpg.rf.2b0acec8be98433d7db1f5ca6f6f4595.jpg
#  extracting: valid/Negative/14027_jpg.rf.1f24efcc3972575b2549cd82fe866dad.jpg
#  extracting: valid/Negative/14030_jpg.rf.75b6ce4dc6e665c82791bbe537ee5528.jpg
#  extracting: valid/Negative/14031_jpg.rf.337ed3b94dd20b8b13d1fde8f99bf14a.jpg
#  extracting: valid/Negative/14033_jpg.rf.0cfe8f8cf8a2e0764f7821f5c0e596cf.jpg
#  extracting: valid/Negative/14039_jpg.rf.568558c1634fb609bf9d4b744b541894.jpg
#  extracting: valid/Negative/14368_jpg.rf.731f7bab81917a3b851c53678b35022c.jpg
#  extracting: valid/Negative/14371_jpg.rf.67b980ccda88bc23165415112432d009.jpg
#  extracting: valid/Negative/14374_jpg.rf.c5c1dec9db46aff2d90ea305db6b386f.jpg
#  extracting: valid/Negative/14377_jpg.rf.f72f63788859b9b8a7a0b2a1198cedf3.jpg
#  extracting: valid/Negative/14378_jpg.rf.69785aedaf606f8f7678a71dafec8b42.jpg
#  extracting: valid/Negative/14385_jpg.rf.4524982f11e978c08d5e1f61d5eb95d3.jpg
#  extracting: valid/Negative/14390_jpg.rf.8f94c2ba99c7d474f293d0751525a0f5.jpg
#  extracting: valid/Negative/14401_jpg.rf.ba3f443272858d4041e7da88a62e60ab.jpg
#  extracting: valid/Negative/14404_jpg.rf.a2c2efe365f9af3389d167dfdc2c5037.jpg
#  extracting: valid/Negative/14410_jpg.rf.fba887f6e214cd5d5e2667673c41c5dd.jpg
#  extracting: valid/Negative/14412_jpg.rf.d316b3421e061dc3befd1b075b21e3f1.jpg
#  extracting: valid/Negative/14413_jpg.rf.0e47f102d0008c10adba9ba3324150f1.jpg
#  extracting: valid/Negative/14417_jpg.rf.08571e77ba924fb0df5a8e16af02261a.jpg
#  extracting: valid/Negative/14426_jpg.rf.120dbe0884088e06af48301ad043e224.jpg
#  extracting: valid/Negative/14428_jpg.rf.284f359e62879b7a24aaa6d9c4210732.jpg
#  extracting: valid/Negative/14431_jpg.rf.40a8b3a0ad9c28147c2c82c703f8e2d9.jpg
#  extracting: valid/Negative/14440_jpg.rf.0077306b1061c582e27eb88412ecd3bc.jpg
#  extracting: valid/Negative/14441_jpg.rf.652e334f6b0d26e59533b7ed24ed85b1.jpg
#  extracting: valid/Negative/14443_jpg.rf.f319d4328215594d9053c44c4e6cc520.jpg
#  extracting: valid/Negative/14452_jpg.rf.9b4a405668b1d49d6b93afb4938cf75c.jpg
#  extracting: valid/Negative/14456_jpg.rf.adad4952311361684bff2d8248ebeea8.jpg
#  extracting: valid/Negative/14460_jpg.rf.3bb607850a362b1b43e175548320b7c3.jpg
#  extracting: valid/Negative/14471_jpg.rf.9a964b058e8a51cc56e689e97460ed79.jpg
#  extracting: valid/Negative/14472_jpg.rf.20193cd5e05aace72e4c7fc697e91e6a.jpg
#  extracting: valid/Negative/14475_jpg.rf.268b192ec2ab1e83bb6568e660600a1f.jpg
#  extracting: valid/Negative/14485_jpg.rf.f09950644a37ccf24f6bcae0e07cd189.jpg
#  extracting: valid/Negative/14489_jpg.rf.b3e32efc3cab17879fabe5e1b4711683.jpg
#  extracting: valid/Negative/14494_jpg.rf.ddf54e2de32cace400c46f83da9206b8.jpg
#  extracting: valid/Negative/14497_jpg.rf.bab8530312eb8d5066603fe0d0f64fc8.jpg
#  extracting: valid/Negative/14498_jpg.rf.32bcaff7a7277eefed8c5d9d8494fa9a.jpg
#  extracting: valid/Negative/14505_jpg.rf.57cbdc78dd6a490b3427b759f8b8ca69.jpg
#  extracting: valid/Negative/14509_jpg.rf.3972440de450998e7d16ed175f641b78.jpg
#  extracting: valid/Negative/15145_jpg.rf.f755d614990b053fb4a8884c99d4bc4c.jpg
#  extracting: valid/Negative/15149_jpg.rf.1fde266017a582264ef78cd28f24e4c5.jpg
#  extracting: valid/Negative/15155_jpg.rf.daa753deaad811f1b3cf5c54117b78a2.jpg
#  extracting: valid/Negative/15162_jpg.rf.874b194c7ad980a47826aec8eccd0805.jpg
#  extracting: valid/Negative/15171_jpg.rf.849953988bb7a3b899e94ace6cc84ca9.jpg
#  extracting: valid/Negative/15173_jpg.rf.2eb1dd0f15c4c7bead98ca3eacf9f00d.jpg
#  extracting: valid/Negative/15189_jpg.rf.fe46e2deebb46b7b85d7f80af2476771.jpg
#  extracting: valid/Negative/15192_jpg.rf.524d47c916d3d13fbb0887c4a7eb18f4.jpg
#  extracting: valid/Negative/15198_jpg.rf.d11632a720f34dbb84d4f42844a0e19a.jpg
#  extracting: valid/Negative/15199_jpg.rf.80a0bf0a5cd1f541228840a9bd06420f.jpg
#  extracting: valid/Negative/15204_jpg.rf.507edfa15f1db0503fd08d1f6afe40dd.jpg
#  extracting: valid/Negative/15205_jpg.rf.e7542fe95659f1842e2e40834209d863.jpg
#  extracting: valid/Negative/15216_jpg.rf.fd210ef8f0240b0826239ba9736c8586.jpg
#  extracting: valid/Negative/15217_jpg.rf.8808e0ea4980f5c51bce00218778edd2.jpg
#  extracting: valid/Negative/15218_jpg.rf.1cc98b5a0d87ff7e8cd27d68d8cd1a75.jpg
#  extracting: valid/Negative/15224_jpg.rf.609ac6eb3d73525e57f5b9b9c20cbf5e.jpg
#  extracting: valid/Negative/15228_jpg.rf.3388e1f2b37538a00a60b0b52f7e00f1.jpg
#  extracting: valid/Negative/15229_jpg.rf.a90970391fdcf771db3b001698041f95.jpg
#  extracting: valid/Negative/15232_jpg.rf.74cabe760af1e9cd05bf82c0b099cc65.jpg
#  extracting: valid/Negative/15237_jpg.rf.808caa3c4d3318112590f2ad5d9f764e.jpg
#  extracting: valid/Negative/15238_jpg.rf.436c2fdf70dfc0d9e46948c08975f645.jpg
#  extracting: valid/Negative/15250_jpg.rf.24201602bedada7af48a42a03198cb75.jpg
#  extracting: valid/Negative/15251_jpg.rf.6bf3e1b2d3985f75e3ce35ba6e70da2d.jpg
#  extracting: valid/Negative/15265_jpg.rf.017c498c328afd77010f5c96442d4b4e.jpg
#  extracting: valid/Negative/15268_jpg.rf.ca886e8ed1c5089e2a558d89e49e3185.jpg
#  extracting: valid/Negative/15269_jpg.rf.ecd9c327abb654e62619cfd2d60eefaa.jpg
#  extracting: valid/Negative/15272_jpg.rf.f98b21595baec2567e15d8a4324cd090.jpg
#  extracting: valid/Negative/15279_jpg.rf.6be886c00a60547d06803a3c45ee70b5.jpg
#  extracting: valid/Negative/15285_jpg.rf.2c517540e64888815d34b81565cedccd.jpg
#  extracting: valid/Negative/15286_jpg.rf.2c0af4aeaa22d99dd81773fcca9e78e9.jpg
#  extracting: valid/Negative/15294_jpg.rf.f52b13343107447449e18b2b1eb67c5f.jpg
#  extracting: valid/Negative/15859_jpg.rf.10dac22a575d799071ee898fe426d911.jpg
#  extracting: valid/Negative/15862_jpg.rf.000b855f804d64970caa69080a8ca7e6.jpg
#  extracting: valid/Negative/15873_jpg.rf.5550b9b6fb3f8d9346152ae6f8e18ef2.jpg
#  extracting: valid/Negative/15886_jpg.rf.0973c9712554c392d2f09a7983dbe5c9.jpg
#  extracting: valid/Negative/15891_jpg.rf.a9eb6a40ecff2b72fe95a1220cbffe9a.jpg
#  extracting: valid/Negative/15896_jpg.rf.4773579c99b32704f10d2e951fc112b7.jpg
#  extracting: valid/Negative/15904_jpg.rf.3c3dd76f219009bd0d2a32c7d4b521e9.jpg
#  extracting: valid/Negative/15908_jpg.rf.1745a8df259ea68b2b73c8afa6c67bed.jpg
#  extracting: valid/Negative/15910_jpg.rf.6ac0c4e6353289701471e739007e38fb.jpg
#  extracting: valid/Negative/15924_jpg.rf.3afb847c4d281f5992153bf8a5ff1ae9.jpg
#  extracting: valid/Negative/15926_jpg.rf.d6d716b17db2200d70c9c9d0edd36249.jpg
#  extracting: valid/Negative/15928_jpg.rf.011e92a53da8d5bf1cb171daabdcb4f4.jpg
#  extracting: valid/Negative/15932_jpg.rf.60f82cc9c37b2c2c2bf76e7da7f837d7.jpg
#  extracting: valid/Negative/15947_jpg.rf.8582e6325d2d48538b2b2d0516772694.jpg
#  extracting: valid/Negative/15948_jpg.rf.657031a7fd28248164d1ffc173805bf7.jpg
#  extracting: valid/Negative/15949_jpg.rf.71c1e59c94c44e8ecfec9d22be0ad56c.jpg
#  extracting: valid/Negative/15950_jpg.rf.b48902c8f496295189bc64dead603de6.jpg
#  extracting: valid/Negative/15957_jpg.rf.3966e7cd63167a5f612b21f861b5cb7a.jpg
#  extracting: valid/Negative/15991_jpg.rf.5842db5e8736543529731ee849b47c8b.jpg
#  extracting: valid/Negative/15993_jpg.rf.33466ddf5fad7a89e8f595ca337495d8.jpg
#  extracting: valid/Negative/15998_jpg.rf.6858b81ccb7d8e795acf4adb5fa1fdae.jpg
#  extracting: valid/Negative/16000_jpg.rf.d20d3e4c363b0db08ccd934c13477f50.jpg
#  extracting: valid/Negative/16009_jpg.rf.c04a15942c82f82e137b38f1b471a2cb.jpg
#  extracting: valid/Negative/16027_jpg.rf.0895e0c5e1c8f3c19fc723aa20e6495e.jpg
#  extracting: valid/Negative/16029_jpg.rf.ca9e1bbe92f944a4c918927f05b72cd2.jpg
#  extracting: valid/Negative/16034_jpg.rf.0c6ab1c937339ad18f08b229ddefbcc8.jpg
#  extracting: valid/Negative/16037_jpg.rf.a8ec42c731a348164db676cd033b2b26.jpg
#  extracting: valid/Negative/16040_jpg.rf.d4292e3fe2ff24bac1292d66c1737814.jpg
#  extracting: valid/Negative/16050_jpg.rf.f70605f32268a38770ad83a843596cdd.jpg
#  extracting: valid/Negative/16053_jpg.rf.cdd947cbe53fe8aa1620c4a7469b5a43.jpg
#  extracting: valid/Negative/16065_jpg.rf.bcbd4bc519276195aec7325e94a19169.jpg
#  extracting: valid/Negative/16081_jpg.rf.36c6e3d879d66b375e6eb710ff853b0c.jpg
#  extracting: valid/Negative/16082_jpg.rf.b07cb330f63f08d36dd18534b6ef8241.jpg
#  extracting: valid/Negative/16083_jpg.rf.41295a8dea746bd807477ac8683624c2.jpg
#  extracting: valid/Negative/16085_jpg.rf.340376027f5828a3fe704f16956ede20.jpg
#  extracting: valid/Negative/16095_jpg.rf.bba6415f13151ed38753053b0e64f0df.jpg
#  extracting: valid/Negative/16100_jpg.rf.ca3ffa98ab915175c78df013e623759a.jpg
#  extracting: valid/Negative/16101_jpg.rf.c94431266cf83a6c9d5010a0d15551ba.jpg
#  extracting: valid/Negative/16105_jpg.rf.4f9f49d9cbc7b18c9876e536e2308853.jpg
#  extracting: valid/Negative/16109_jpg.rf.4a522a47f10fbde03f6ec43b31e79ead.jpg
#  extracting: valid/Negative/16119_jpg.rf.d837aecb1e314f52bbca229fcf87c5ae.jpg
#  extracting: valid/Negative/16124_jpg.rf.07f0ddc72d3b8289b5ad7123d5394f8a.jpg
#  extracting: valid/Negative/16126_jpg.rf.108e503ede50f7b8b0f5602df5e29b82.jpg
#  extracting: valid/Negative/16127_jpg.rf.d559834c586739ff3ab4fb212992d32c.jpg
#  extracting: valid/Negative/16131_jpg.rf.4384c26216ec1b340879ee04f1cddeda.jpg
#  extracting: valid/Negative/16145_jpg.rf.e28c10652b83b77afbac3b778038591c.jpg
#  extracting: valid/Negative/16160_jpg.rf.191646fab92bac119cb6cf710fe004a5.jpg
#  extracting: valid/Negative/16168_jpg.rf.cae9b7edaa2d0b7683741493be7c0340.jpg
#  extracting: valid/Negative/16169_jpg.rf.06c48629cc30064d4bad6fb125714dc8.jpg
#  extracting: valid/Negative/16173_jpg.rf.43f1c48af5959b957f36ddc7fcfb3361.jpg
#  extracting: valid/Negative/16176_jpg.rf.3394c618f029b20aac6d1beb8e4adbe7.jpg
#  extracting: valid/Negative/16183_jpg.rf.4e26657cad0fde4c839826add5e7d470.jpg
#  extracting: valid/Negative/16191_jpg.rf.b8870f195446a9841ea001f4b95990c4.jpg
#  extracting: valid/Negative/16192_jpg.rf.fb296f49e97530e02878964e4e1945a7.jpg
#  extracting: valid/Negative/16199_jpg.rf.5ae59c63fece560f2f5cbc70bb06ec47.jpg
#  extracting: valid/Negative/16200_jpg.rf.8aa55a0aa2e94a7640070e355d458317.jpg
#  extracting: valid/Negative/16206_jpg.rf.d02798f791d189b322d2afb5cebc0623.jpg
#  extracting: valid/Negative/16210_jpg.rf.af17d6ecdd39d5fda68b8023593a3338.jpg
#  extracting: valid/Negative/16213_jpg.rf.f585a8ea0128767e7e8c18490c77713d.jpg
#  extracting: valid/Negative/16219_jpg.rf.99c3f519cc4b826f7eabccaf8a323d41.jpg
#  extracting: valid/Negative/16222_jpg.rf.184a693c6d8af29ddddce49d2427081e.jpg
#  extracting: valid/Negative/16225_jpg.rf.c6b7c0e0f4b9b5dab4d6af16b9045d6d.jpg
#  extracting: valid/Negative/16226_jpg.rf.4714d8192f805245a9b01352d064972a.jpg
#  extracting: valid/Negative/16233_jpg.rf.701665273cb42dc2874045de316397f8.jpg
#  extracting: valid/Negative/16239_jpg.rf.b426845800e469e219160bc60c1167e4.jpg
#  extracting: valid/Negative/16245_jpg.rf.127c8d2dab6cba1a370760a57a0b9df8.jpg
#  extracting: valid/Negative/16253_jpg.rf.a337ffb35ed7e925d38c66c529b3a348.jpg
#  extracting: valid/Negative/16275_jpg.rf.d04c4010d408935098c4415a6cdc3d24.jpg
#  extracting: valid/Negative/16276_jpg.rf.dd3aa5d4980d02a88b893fcb88a884a8.jpg
#  extracting: valid/Negative/16277_jpg.rf.f57d1e6f7c5d4006c4b1f2345ee5dce4.jpg
#  extracting: valid/Negative/16282_jpg.rf.05be5ce2a8d3dca6c41bdf2de2da605e.jpg
#  extracting: valid/Negative/16285_jpg.rf.07f6154052a2cca0487671babe829cb2.jpg
#  extracting: valid/Negative/16286_jpg.rf.e2dbd10dffe35bf56bbd03aa0e7724e7.jpg
#  extracting: valid/Negative/16287_jpg.rf.e3da595c990877f55c1ac292445229af.jpg
#  extracting: valid/Negative/16288_jpg.rf.b8f5422dd36956b4952824012865bef7.jpg
#  extracting: valid/Negative/16299_jpg.rf.0a3af10359535bf3741350f28722b3eb.jpg
#  extracting: valid/Negative/16301_jpg.rf.3e6c00cb4d730cb0a7f5415c5b082a7b.jpg
#  extracting: valid/Negative/16306_jpg.rf.822dbc567355051f895ab689f1af54d4.jpg
#  extracting: valid/Negative/16308_jpg.rf.d888becd5386698dbbe1835beef9dc0a.jpg
#  extracting: valid/Negative/16309_jpg.rf.534d0dbf59541ef4040a1ac089232935.jpg
#  extracting: valid/Negative/16310_jpg.rf.73436e42e9306042bda3cad8e0739e06.jpg
#  extracting: valid/Negative/16320_jpg.rf.f9a8e76e74974bef1efd9490f19ea658.jpg
#  extracting: valid/Negative/16324_jpg.rf.a292d4c77fcaa2138b9a914c683c5524.jpg
#  extracting: valid/Negative/16329_jpg.rf.369e21a12f6d736e69e9d052bb220fbb.jpg
#  extracting: valid/Negative/16331_jpg.rf.a64095f94c6bf0167c8464680f22951b.jpg
#  extracting: valid/Negative/16333_jpg.rf.e91d21e33831c270856037619b441f59.jpg
#  extracting: valid/Negative/16340_jpg.rf.c41a9af0f4b0eef241c9cb7de75b15ef.jpg
#  extracting: valid/Negative/16353_jpg.rf.dea91fb9b316ddb5e7c36266800de9e0.jpg
#  extracting: valid/Negative/16376_jpg.rf.352a12f4ffac3f17a09ef974ab62900c.jpg
#  extracting: valid/Negative/16382_jpg.rf.2009b024036fba41746b39c23e866abf.jpg
#  extracting: valid/Negative/16385_jpg.rf.b858e45351e1fda67f7982de65e75e86.jpg
#  extracting: valid/Negative/16412_jpg.rf.4fd32a27ecbb5422905b329bfffcbd94.jpg
#  extracting: valid/Negative/16415_jpg.rf.358a79270348107b3a2f7e80d53f62f0.jpg
#  extracting: valid/Negative/16419_jpg.rf.da4183188a77298c570db4fa68fe08db.jpg
#  extracting: valid/Negative/16422_jpg.rf.3c7a245f0a8ca08281716cd315baa91b.jpg
#  extracting: valid/Negative/16431_jpg.rf.03e17f42090ab2e94a768c5740649f12.jpg
#  extracting: valid/Negative/16606_jpg.rf.0b23ae6502c74cafb47a54dcd1948d47.jpg
#  extracting: valid/Negative/16608_jpg.rf.7c5a55b68346879d0b97f7486100008b.jpg
#  extracting: valid/Negative/16610_jpg.rf.acc454c66386693bfcee0f4ada18088f.jpg
#  extracting: valid/Negative/16642_jpg.rf.48bcf44fe303f989446838cb9aee2796.jpg
#  extracting: valid/Negative/16643_jpg.rf.a8a2e6e851effaf24f7a7e3c187ffed2.jpg
#  extracting: valid/Negative/16650_jpg.rf.a48f571a5340a319b9e5726ab0e6aee8.jpg
#  extracting: valid/Negative/16654_jpg.rf.7addfa4ee49882dafe7b9913ed1361b3.jpg
#  extracting: valid/Negative/16666_jpg.rf.f7fea318a0f148fabd8ab9693407fc4c.jpg
#  extracting: valid/Negative/16671_jpg.rf.24c2c6cec8f0196cfab3c9559d9674c1.jpg
#  extracting: valid/Negative/16675_jpg.rf.43896c0236b468cecc38b20aaed152dc.jpg
#  extracting: valid/Negative/16679_jpg.rf.58931079606a89d61797bf360e2c8c20.jpg
#  extracting: valid/Negative/16683_jpg.rf.87dcb4f40a009b070ff5a4503a92f1d3.jpg
#  extracting: valid/Negative/16684_jpg.rf.a9814af418f4b29e3c53fbe327ff5eb3.jpg
#  extracting: valid/Negative/16685_jpg.rf.5efd4d5043c90c7ee3dfc8ae69338a3d.jpg
#  extracting: valid/Negative/16688_jpg.rf.67b47636adb52d43b5dda171752baa2b.jpg
#  extracting: valid/Negative/16691_jpg.rf.b9c0966cad6fe43b706bf55d1813cd5e.jpg
#  extracting: valid/Negative/16696_jpg.rf.f111a04fd2924a32cf8a8e193a0f847e.jpg
#  extracting: valid/Negative/16698_jpg.rf.cf22cec6bddbc1e4e1e897df25eba547.jpg
#  extracting: valid/Negative/16699_jpg.rf.c2877945d470eed9daff98ac93f95684.jpg
#  extracting: valid/Negative/16707_jpg.rf.e1269f90fb44b352a09ca597bebfc0a9.jpg
#  extracting: valid/Negative/16717_jpg.rf.c142f3c0fd935db3db4c1e1ccc2bc008.jpg
#  extracting: valid/Negative/16718_jpg.rf.8dd51e5bd8ca9dde68ea22f84200f1d3.jpg
#  extracting: valid/Negative/16726_jpg.rf.ca0623dbd95e8d281baec93977363a8a.jpg
#  extracting: valid/Negative/16727_jpg.rf.15d81da854b022cb4dc8a83db22d3e5a.jpg
#  extracting: valid/Negative/16731_jpg.rf.96d2fa8b1542173fcb9df2ff8d03cd3f.jpg
#  extracting: valid/Negative/16737_jpg.rf.b1f768c331fdeca5b5281c1c9e1d1a95.jpg
#  extracting: valid/Negative/16762_jpg.rf.108dc0fdc5742a60a13e629eb31e0548.jpg
#  extracting: valid/Negative/16766_jpg.rf.add66a3e7432319665252137baa9495c.jpg
#  extracting: valid/Negative/16769_jpg.rf.444f1aaa7ddbff255754d50342acb222.jpg
#  extracting: valid/Negative/16770_jpg.rf.7c16847492a124d06b37f92af5dea0a7.jpg
#  extracting: valid/Negative/16773_jpg.rf.a53468508f3aba75b5deb6e1b1f82491.jpg
#  extracting: valid/Negative/16785_jpg.rf.1a93985de89581d443ab8c1da47149ad.jpg
#  extracting: valid/Negative/16791_jpg.rf.4390c96169036f2465ec5245eb8ac37a.jpg
#  extracting: valid/Negative/16801_jpg.rf.43c204a695248115404f64d60adcd2be.jpg
#  extracting: valid/Negative/16803_jpg.rf.6a9741a9948b1b80ab5c4b04ac211f82.jpg
#  extracting: valid/Negative/16805_jpg.rf.a0b3d65534582ae4d020c055f3a9812b.jpg
#  extracting: valid/Negative/16808_jpg.rf.36f51ab4c2f956f3d8b37db3624f5226.jpg
#  extracting: valid/Negative/16810_jpg.rf.791b336adced432f3002c4605edcf95a.jpg
#  extracting: valid/Negative/16822_jpg.rf.56ba16b82c1cecf7baacc7580f7f08ed.jpg
#  extracting: valid/Negative/16824_jpg.rf.1f3c502f7f2bc5cf5582faf94ae50116.jpg
#  extracting: valid/Negative/16831_jpg.rf.7d92e0fa7ae365269c258839afb42d2d.jpg
#  extracting: valid/Negative/16833_jpg.rf.be32d683b346ac3430976ce4dfb9e64c.jpg
#  extracting: valid/Negative/16844_jpg.rf.83c202319cea5d32241184fece8e1cee.jpg
#  extracting: valid/Negative/16846_jpg.rf.276f4b4f5b3fd20350839ebed17e416e.jpg
#  extracting: valid/Negative/16849_jpg.rf.f6666302b071e51dbd36ed76172f238e.jpg
#  extracting: valid/Negative/16856_jpg.rf.26e4c94ee50a9d491ce212fb334218de.jpg
#  extracting: valid/Negative/16863_jpg.rf.700105d4d92f57db3bde9451d49b2bc4.jpg
#  extracting: valid/Negative/16874_jpg.rf.88a65aad28ee48f7d69758f0f7176713.jpg
#  extracting: valid/Negative/16875_jpg.rf.9c8c75d16c1409fc162eb1cbc7fe18ce.jpg
#  extracting: valid/Negative/16883_jpg.rf.b617a91404888421fcf4b35c9e9daa73.jpg
#  extracting: valid/Negative/16887_jpg.rf.55ce519a9b579f64dc3bf5d7188f91fb.jpg
#  extracting: valid/Negative/16889_jpg.rf.c5f632499a84caee345687c14c83cf7d.jpg
#  extracting: valid/Negative/16890_jpg.rf.4054be1295f38a7b4827f3495ca521e8.jpg
#  extracting: valid/Negative/16892_jpg.rf.606ac3874bf4ba907a52ec6b8fce16fd.jpg
#  extracting: valid/Negative/16905_jpg.rf.baf4d607c85ab9b19e125ac52402e06a.jpg
#  extracting: valid/Negative/16918_jpg.rf.8178275e7be4f556e06e6fb67b571db3.jpg
#  extracting: valid/Negative/16923_jpg.rf.ece08348437b92b265b1a7f8cb134eda.jpg
#  extracting: valid/Negative/16924_jpg.rf.f2aba386d8bec01ee501107ab6a09304.jpg
#  extracting: valid/Negative/16932_jpg.rf.6f01f5d6b2b0233f8fc55c9f7e64a8e0.jpg
#  extracting: valid/Negative/16947_jpg.rf.ea815264079b2472e93a3fb9df3fa171.jpg
#  extracting: valid/Negative/16951_jpg.rf.cb61c5975d7a60fc636a76190bd3459f.jpg
#  extracting: valid/Negative/16954_jpg.rf.e8301df25fb9a8249678e9d0c67830f2.jpg
#  extracting: valid/Negative/16956_jpg.rf.0c718b22538693907bcdfa685e541b75.jpg
#  extracting: valid/Negative/16961_jpg.rf.65f02ed3c7518c0d6a3d165fe3da41b8.jpg
#  extracting: valid/Positive/19897_jpg.rf.acf87caf72b34a25fa7153eaf578ee73.jpg
#  extracting: valid/Positive/19898_jpg.rf.0a612c6552658ad75577987989eba52f.jpg
#  extracting: valid/Positive/19899_jpg.rf.6319b6f39d83577b45212f43cb7b70e5.jpg
#  extracting: valid/Positive/19912_jpg.rf.8bea32c03fbb9441f4a6b47e3d6908f9.jpg
#  extracting: valid/Positive/19916_jpg.rf.3f737706c0081060cbe9e4b0cbc108c8.jpg
#  extracting: valid/Positive/19920_jpg.rf.89786e7bfdcfec105aab7360e13ea682.jpg
#  extracting: valid/Positive/19921_jpg.rf.a74fe106b5579a79246ed5f66e573561.jpg
#  extracting: valid/Positive/19922_jpg.rf.2b2e6afbf4a75732a79366928a5aaf90.jpg
#  extracting: valid/Positive/19923_jpg.rf.815d74ccd5e024b0e1e8644c0a2bbc37.jpg
#  extracting: valid/Positive/19925_jpg.rf.6a8665b2dae8b4c916aedce63992be50.jpg
#  extracting: valid/Positive/19926_jpg.rf.5ed0cec1ce479a14254be603df60f237.jpg
#  extracting: valid/Positive/19932_jpg.rf.a65d6a4e79b5c1d00a1e9a0070de2250.jpg
#  extracting: valid/Positive/19939_jpg.rf.47c8346bbe6adab5196577e16c44d005.jpg
#  extracting: valid/Positive/19945_jpg.rf.5d89b72f25c298d86e7e666f06c00e96.jpg
#  extracting: valid/Positive/19946_jpg.rf.75ea77dfe85090ebc262032d02fcb0ac.jpg
#  extracting: valid/Positive/19947_jpg.rf.d3147ecc813bc67482c2b7935d273aa7.jpg
#  extracting: valid/Positive/19948_jpg.rf.ac45a2a82c5b3a4289bb54a243791492.jpg
#  extracting: valid/Positive/19951_jpg.rf.7dea634a1dd6b8e8e90e17ea8ffb2208.jpg
#  extracting: valid/Positive/19952_jpg.rf.641bcdb4722edde3a4f1e66308d89a90.jpg
#  extracting: valid/Positive/19955_jpg.rf.28453340d2cd25abde02dc79ab171647.jpg
#  extracting: valid/Positive/19956_jpg.rf.78c86adbfad0321a1fdedb035d475dc4.jpg
#  extracting: valid/Positive/19964_jpg.rf.3556aab0d7ecd7002b2a78ecf3a1e969.jpg
#  extracting: valid/Positive/19971_jpg.rf.180cfcdafae4c5b6af25fedc23cca2c1.jpg
#  extracting: valid/Positive/19972_jpg.rf.7655582bc1eafe75dea388be22955768.jpg
#  extracting: valid/Positive/19981_jpg.rf.315a015b67c23e949532398314e4d084.jpg
#  extracting: valid/Positive/19985_jpg.rf.c6cca6fc6d0a1d0ca944dbc6a98a086e.jpg
#  extracting: valid/Positive/19989_jpg.rf.91da34897d5e9ef59b87d810c03722fe.jpg

# %% [markdown]
# Next, convert the folder structure dataset into a PyTorch dataset format using PyTorch's ImageFolder dataset structure:

# %%
import torchvision
from torchvision.transforms import ToTensor

train_ds = torchvision.datasets.ImageFolder('/content/train/', transform=ToTensor())
valid_ds = torchvision.datasets.ImageFolder('/content/valid/', transform=ToTensor())
test_ds = torchvision.datasets.ImageFolder('/content/test/', transform=ToTensor())

# %% [markdown]
# ## Define the Model
#
# Here we define the model.
#
# The model itself uses a linear layer on top of a pre-trained `ViTModel`. We place a linear layer on top of the last hidden state of the [CLS] token, which serves as a good representation of an entire image. We also add dropout for regularization.
#
# **Note:** The Vision Transformer pretrained model can be used as a regular PyTorch layer.

# %%
from transformers import ViTModel
from transformers.modeling_outputs import SequenceClassifierOutput
import torch.nn as nn
import torch.nn.functional as F

class ViTForImageClassification(nn.Module):
    def __init__(self, num_labels=3):
        super(ViTForImageClassification, self).__init__()
        self.vit = ViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
        self.dropout = nn.Dropout(0.1)
        self.classifier = nn.Linear(self.vit.config.hidden_size, num_labels)
        self.num_labels = num_labels

    def forward(self, pixel_values, labels):
        outputs = self.vit(pixel_values=pixel_values)
        output = self.dropout(outputs.last_hidden_state[:,0])
        logits = self.classifier(output)

        loss = None
        if labels is not None:
          loss_fct = nn.CrossEntropyLoss()
          loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))
        if loss is not None:
          return logits, loss.item()
        else:
          return logits, None

# %% [markdown]
# ## Define the Model Parameters
#
# To train this model, we will train in 3 epochs, with a batch size of 10 and a learning rate of 2e-5:

# %%
EPOCHS = 3
BATCH_SIZE = 10
LEARNING_RATE = 2e-5

# %% [markdown]
# We will use the pretrained Vision Transformer feature extractor, an Adam Optimizer, and a Cross Entropy Loss function.

# %%
from transformers import ViTFeatureExtractor
import torch.nn as nn
import torch
# Define Model
model = ViTForImageClassification(len(train_ds.classes))
# Feature Extractor
feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224-in21k')
# Adam Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
# Cross Entropy Loss
loss_func = nn.CrossEntropyLoss()
# Use GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if torch.cuda.is_available():
    model.cuda()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/vit/feature_extraction_vit.py:30: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %% [markdown]
# ## Train the Model

# %%
import torch.utils.data as data
from torch.autograd import Variable
import numpy as np

print("Number of train samples: ", len(train_ds))
print("Number of test samples: ", len(test_ds))
print("Detected Classes are: ", train_ds.class_to_idx)

train_loader = data.DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  num_workers=4)
test_loader  = data.DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)

# Train the model
for epoch in range(EPOCHS):
  for step, (x, y) in enumerate(train_loader):
    # Change input array into list with each batch being one element
    x = np.split(np.squeeze(np.array(x)), BATCH_SIZE)
    # Remove unecessary dimension
    for index, array in enumerate(x):
      x[index] = np.squeeze(array)
    # Apply feature extractor, stack back into 1 tensor and then convert to tensor
    x = torch.tensor(np.stack(feature_extractor(x)['pixel_values'], axis=0))
    # Send to GPU if available
    x, y  = x.to(device), y.to(device)
    b_x = Variable(x)   # batch x (image)
    b_y = Variable(y)   # batch y (target)
    # Feed through model
    output, loss = model(b_x, None)
    # Calculate loss
    if loss is None:
      loss = loss_func(output, b_y)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

    if step % 50 == 0:
      # Get the next batch for testing purposes
      test = next(iter(test_loader))
      test_x = test[0]
      # Reshape and get feature matrices as needed
      test_x = np.split(np.squeeze(np.array(test_x)), BATCH_SIZE)
      for index, array in enumerate(test_x):
        test_x[index] = np.squeeze(array)
      test_x = torch.tensor(np.stack(feature_extractor(test_x)['pixel_values'], axis=0))
      # Send to appropirate computing device
      test_x = test_x.to(device)
      test_y = test[1].to(device)
      # Get output (+ respective class) and compare to target
      test_output, loss = model(test_x, test_y)
      test_output = test_output.argmax(1)
      # Calculate Accuracy
      accuracy = (test_output == test_y).sum().item() / BATCH_SIZE
      print('Epoch: ', epoch, '| train loss: %.4f' % loss, '| test accuracy: %.2f' % accuracy)
# Out:
# Number of train samples:  80436
# Number of test samples:  3849
# Detected Classes are:  {'Negative': 0, 'Positive': 1}
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# It looks like you are trying to rescale already rescaled images. If the input images have pixel values between 0 and 1, set `do_rescale=False` to avoid rescaling them again.
# Epoch:  0 | train loss: 0.6925 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.6927 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.7044 | test accuracy: 0.40
# Epoch:  0 | train loss: 0.7104 | test accuracy: 0.40
# Epoch:  0 | train loss: 0.6877 | test accuracy: 0.60
# Epoch:  0 | train loss: 0.7078 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.6927 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.6923 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.7551 | test accuracy: 0.20
# Epoch:  0 | train loss: 0.7087 | test accuracy: 0.30
# Epoch:  0 | train loss: 0.6224 | test accuracy: 0.90
# Epoch:  0 | train loss: 0.7077 | test accuracy: 0.20
# Epoch:  0 | train loss: 0.6901 | test accuracy: 0.80
# Epoch:  0 | train loss: 0.6966 | test accuracy: 0.40
# Epoch:  0 | train loss: 0.6925 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.7089 | test accuracy: 0.30
# Epoch:  0 | train loss: 0.6984 | test accuracy: 0.40
# Epoch:  0 | train loss: 0.7143 | test accuracy: 0.10
# Epoch:  0 | train loss: 0.6992 | test accuracy: 0.40
# Epoch:  0 | train loss: 0.6906 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.6932 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.6932 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.7049 | test accuracy: 0.40
# Epoch:  0 | train loss: 0.6897 | test accuracy: 0.60
# Epoch:  0 | train loss: 0.6971 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.6915 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.7001 | test accuracy: 0.30
# Epoch:  0 | train loss: 0.6977 | test accuracy: 0.40
# Epoch:  0 | train loss: 0.6937 | test accuracy: 0.60
# Epoch:  0 | train loss: 0.6921 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.7158 | test accuracy: 0.40
# Epoch:  0 | train loss: 0.6955 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.7071 | test accuracy: 0.30
# Epoch:  0 | train loss: 0.6898 | test accuracy: 0.60
# Epoch:  0 | train loss: 0.6615 | test accuracy: 0.80
# Epoch:  0 | train loss: 0.6807 | test accuracy: 0.70
# Epoch:  0 | train loss: 0.6926 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.6862 | test accuracy: 0.60
# Epoch:  0 | train loss: 0.6796 | test accuracy: 0.60
# Epoch:  0 | train loss: 0.6898 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.6778 | test accuracy: 0.60
# Epoch:  0 | train loss: 0.7106 | test accuracy: 0.40
# Epoch:  0 | train loss: 0.6759 | test accuracy: 0.70
# Epoch:  0 | train loss: 0.6899 | test accuracy: 0.80
# Epoch:  0 | train loss: 0.6869 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.7087 | test accuracy: 0.40
# Epoch:  0 | train loss: 0.7007 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.6973 | test accuracy: 0.30
# Epoch:  0 | train loss: 0.6884 | test accuracy: 0.70
# Epoch:  0 | train loss: 0.6968 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.6891 | test accuracy: 0.70
# Epoch:  0 | train loss: 0.6933 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.7156 | test accuracy: 0.30
# Epoch:  0 | train loss: 0.7100 | test accuracy: 0.40
# Epoch:  0 | train loss: 0.6881 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.6917 | test accuracy: 0.50
# Epoch:  0 | train loss: 0.6872 | test accuracy: 0.70

# %% [markdown]
# ## Evaluate on a Test Image
#
# Finally, let's evaluate the model on a test image:

# %%
import matplotlib.pyplot as plt
import numpy as np

EVAL_BATCH = 1
eval_loader  = data.DataLoader(valid_ds, batch_size=EVAL_BATCH, shuffle=True, num_workers=4)
# Disable grad
with torch.no_grad():

  inputs, target = next(iter(eval_loader))
  # Reshape and get feature matrices as needed
  print(inputs.shape)
  inputs = inputs[0].permute(1, 2, 0)
  # Save original Input
  originalInput = inputs
  for index, array in enumerate(inputs):
    inputs[index] = np.squeeze(array)
  inputs = torch.tensor(np.stack(feature_extractor(inputs)['pixel_values'], axis=0))

  # Send to appropriate computing device
  inputs = inputs.to(device)
  target = target.to(device)

  # Generate prediction
  prediction, loss = model(inputs, target)

  # Predicted class value using argmax
  predicted_class = np.argmax(prediction.cpu())
  value_predicted = list(valid_ds.class_to_idx.keys())[list(valid_ds.class_to_idx.values()).index(predicted_class)]
  value_target = list(valid_ds.class_to_idx.keys())[list(valid_ds.class_to_idx.values()).index(target)]

  # Show result
  plt.imshow(originalInput)
  plt.xlim(224,0)
  plt.ylim(224,0)
  plt.title(f'Prediction: {value_predicted} - Actual target: {value_target}')
  plt.show()
# Out:
# torch.Size([1, 3, 224, 224])

# %% [markdown]
# ## Save the Entire Model
#
# We can save the entire model as follows:

# %%
torch.save(model, '/content/model.pt')

# %% [markdown]
# ## Export Trained Model
#
# Now that you have trained your custom vision transformer, you can export the trained model you have made here for inference on your device elsewhere

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %cp /content/model.pt /content/gdrive/My\ Drive
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Use your Exported Model

# %%
MODEL_PATH = '/content/model.pt'
model = torch.load(MODEL_PATH)
model.eval()
# Out:
# ViTForImageClassification(
#   (vit): ViTModel(
#     (embeddings): ViTEmbeddings(
#       (patch_embeddings): PatchEmbeddings(
#         (projection): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ViTEncoder(
#       (layer): ModuleList(
#         (0): ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (1): ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (2): ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (3): ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (4): ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (5): ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (6): ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (7): ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (8): ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (9): ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (10): ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (11): ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (pooler): ViTPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=3, bias=True)
# )
